# %% [markdown]
# ![alternative text](Questions/Photos/8.png)

# %%
# Importing in-built libraries of python
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

# %%
cutoff_low = 0.3
cutoff_high = 0.6

# %%
N = 11 # Type - I
b = signal.firwin(N, [cutoff_low, cutoff_high], window = 'black', pass_zero = True)
a = 1
print(np.round(b, decimals = 2))
# Out:
# [ 0.   -0.01  0.02  0.14 -0.04  0.78 -0.04  0.14  0.02 -0.01  0.  ]

# %%
W, h = signal.freqz(b,a)
h_db = 20 * np.log10(abs(h))
plt.figure (figsize = (10, 4))
plt.plot (W/max(W), h_db)
plt.grid()
plt.title ('Om Digital LPF Blackman', fontsize = 15)
plt.xlabel ('W', fontsize = 12)
plt.ylabel ('H(w)', fontsize = 12)
# Out:
# Text(0, 0.5, 'H(w)')
